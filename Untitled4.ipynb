# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts.cumsum().plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.038001  1.186102  2.004968 -1.231532
# 2000-01-02  0.084572 -1.232547  1.415986  0.613881
# 2000-01-03  0.179869 -0.130474  1.398684  0.112351
# 2000-01-04 -0.246224 -1.556573  0.818814  0.507517
# 2000-01-05 -1.144149  0.687057  0.464860 -1.346872

# %%
df.cumsum(axis = 0).plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df.head()
# Out:
#           B         C
# 0  0.251958 -1.123171
# 1  1.942595 -1.850245
# 2  1.803403 -1.131029
# 3  2.644802 -1.499459
# 4  2.963532 -3.290161

# %%
df.plot(y='B', x=df.index)

# %%
plt.figure();

.plot(kind='bar');
# Out:
#   File "<ipython-input-25-b45b24006824>", line 3
#     .plot(kind='bar');
#     ^
# SyntaxError: invalid syntax

# %%
plt.figure();
df.iloc[5].plot(kind = 'bar')
plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(100, 4), columns=['a', 'b', 'c', 'd'])
df2 = df2.applymap(lambda x: x * 1)

# %%
df2.plot.bar();

# %%
df2.apply(np.sum, axis = 0).plot.bar()

# %%
pd.DataFrame((df2.apply(np.sum, axis = 0))[['a', 'b']])
# Out:
#            0
# a  48.331675
# b  47.137174

# %%
df4 = pd.DataFrame({'a': np.random.normal(20, 10, 100) + 1, 'b': np.random.normal(40, 30, 100)}, columns=['a', 'b'])

# %%
df4
# Out:
#             a          b
# 0    6.263971  23.709651
# 1   17.619803  46.873712
# 2   25.318400  42.617791
# 3   24.318776  23.135873
# 4   13.040477  47.476675
# 5   23.269867  -6.614924
# 6    3.969333  46.258299
# 7   29.162894  27.134340
# 8    7.139270  38.052124
# 9   20.161439   4.006971
# 10  12.476260  10.191974
# 11  17.019628   3.553057
# 12  39.926603  39.796184
# 13  23.615202   5.653400
# 14  17.964927  74.061139
# 15  19.060522  64.053574
# 16  22.556501  77.635438
# 17   9.704367  31.217447
# 18  15.463781  11.263145
# 19  21.734233  44.495585
# 20  27.305681  61.279115
# 21  17.123412  30.998070
# 22  17.893037  15.500435
# 23  -1.368422  57.232015
# 24  24.161810  50.719810
# 25  28.313127  56.185060
# 26  12.281437  66.974438
# 27  44.886524  34.416940
# 28  17.135424  74.314354
# 29  19.356456  65.054283
# ..        ...        ...
# 70   5.230179  82.310360
# 71  16.612220  65.691291
# 72  26.595847  79.192877
# 73  32.050229  27.701202
# 74  19.013909  46.856978
# ...

# %%
plt.figure()
df4.plot.hist(alpha=0.5)

# %%
df4.plot.hist(stacked=False, bins=20)

# %%
df4.plot.hist(stacked=True, bins=20, color = ['b', 'r'])

# %%
df4['a'].plot.hist(color = 'b')

# %%
df4['b'].plot.hist(color = 'r', label = 'a')
df4['a'].plot.hist(color = 'b')
plt.xlim(-20, 130)
plt.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-714f4ee6002d> in <module>()
#       2 df4['a'].plot.hist(color = 'b')
#       3 plt.xlim(-20, 130)
# ----> 4 plt.labels()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'labels'
